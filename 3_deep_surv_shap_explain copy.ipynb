# %%
import pandas as pd
import numpy as np

df = pd.read_csv("LUAD_multimodal_dataset.csv")

df.head()
# Out:
#   PatientID survival_label  Longest.Diameter..mm.  \
# 0     R0004           Long                  45.50
# 1     R0013           Long                  41.82
# 2     R0017           Long                  18.95
# 3     R0018          Short                  35.04
# 4     R0019          Short                  31.87
#
#    Short.Axis...Longest.Diameter..mm..  Short.Axis..mm.  Mean..HU.  \
# 0                              1520.73            33.42     -20.13
# 1                               617.67            14.77      -9.56
# 2                               240.46            12.69     -73.58
# 3                              1086.57            31.01      28.45
# 4                               613.64            19.25     -30.00
#
#    StdDev..HU.  Volume..cm..  X5a_3D_MacSpic_NumberOf  \
# 0       136.80         33.06                        0
# 1       119.63         14.78                        0
# 2       151.36          1.76                        0
# 3        93.49         16.85                        0
# 4       146.40         10.97                        0
#
#    X8a_3D_Is_Attached_To_Pleural_Wall  ...  \
# 0                                   0  ...
# 1                                   1  ...
# 2                                   1  ...
# 3                                   1  ...
# 4                                   1  ...
#
#    X3D.Wavelet.decomposition...P1.L2.C5.Layer.1  \
# 0                                  25833.098760
# 1                                  15237.079170
# 2                                   1585.785644
# 3                                  12430.672920
# 4                                   8299.075649
#
#    X3D.Wavelet.decomposition...P1.L2.C6.Layer.1  \
# 0                                   8449.116111
# 1                                   4561.750068
# 2                                   2164.498445
# 3                                   3005.110061
# 4                                   2753.117372
#
#    X3D.Wavelet.decomposition...P1.L2.C7.Layer.1  \
# 0                                    737.184747
# 1                                    613.539088
# 2                                     59.819492
# 3                                    400.538246
# 4                                     89.089983
#
#    X3D.Wavelet.decomposition...P1.L2.C8.Layer.1  Convexity_Mean  \
# 0                                   6172.425054        0.863500
# 1                                   3699.644891        0.845099
# 2                                    491.460387        0.931435
# 3                                   3257.483750        0.917999
# 4                                    381.985943        0.931737
#
#    Conv_Area_Perim  IsAttached  Std_Conv  \
# 0         0.642984    0.863500  0.097923
# 1         0.866819    0.807820  0.027609
# 2         0.918455    0.931435  0.013920
# 3         0.897987    0.917999  0.025730
# 4         0.946039    0.860215  0.039337
#
#                                               Report  \
# 0  CT scan shows left hilum 45.5 mm mass, Stage I...
# 1  CT scan shows right lower lobe 41.82 mm mass, ...
# 2  Stage IV left hilum tumor measuring 18.95 mm. ...
# 3  left hilum lesion (35.04 mm) consistent with S...
# 4  Stage IV right lower lobe tumor measuring 31.8...
#
#                                            ImagePath
# 0  C:\Users\sohel\Downloads\Ai_health\LUAD_CT_SUR...
# 1  C:\Users\sohel\Downloads\Ai_health\LUAD_CT_SUR...
# 2  C:\Users\sohel\Downloads\Ai_health\LUAD_CT_SUR...
# 3  C:\Users\sohel\Downloads\Ai_health\LUAD_CT_SUR...
# 4  C:\Users\sohel\Downloads\Ai_health\LUAD_CT_SUR...
#
# [5 rows x 227 columns]

# %%
print(df["survival_label"].unique())
# Out:
# ['Long' 'Short']

# %%
df["survival_label"] = df["survival_label"].astype(str).str.lower()
y = (df["survival_label"] == "long").astype(int).to_numpy()
print("y values:", np.unique(y))
# Out:
# y values: [0 1]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
drop_cols = ["PatientID", "survival_label", "Report", "ImagePath", "SegPath"]

radiomics_cols = [
    c for c in df.columns
    if c not in drop_cols and df[c].dtype != "object"
]

print("Numeric radiomics:", len(radiomics_cols))
# Out:
# Numeric radiomics: 223

# %%
X_rad = df[radiomics_cols].apply(pd.to_numeric, errors="coerce").fillna(0).values

# %%
emb = np.load("text_embeddings.npy")
print(emb.shape)
# Out:
# (40, 768)

# %%
X = np.hstack([X_rad, emb])
print(X.shape)
assert X.shape[0] == df.shape[0], "Rows mismatch!"
# Out:
# (40, 991)

# %%
y = df["survival_label"].astype(str).str.lower()

y = y.replace({"long": 1, "short": 0}).astype(int)
print("Labels:", np.unique(y))
# Out:
# Labels: [0 1]
# C:\Users\sohel\AppData\Local\Temp\ipykernel_33688\3862994049.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y = y.replace({"long": 1, "short": 0}).astype(int)

# %%
# --- Clean labels ---
df["survival_label"] = df["survival_label"].astype(str).str.lower()
y = (df["survival_label"] == "long").astype(int).to_numpy()

# --- Scale features ---
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# --- Train/Val split ---
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

X_train = torch.tensor(X_train, dtype=torch.float32).to(device)
X_val   = torch.tensor(X_val,   dtype=torch.float32).to(device)
y_train = torch.tensor(y_train.reshape(-1,1), dtype=torch.float32).to(device)
y_val   = torch.tensor(y_val.reshape(-1,1), dtype=torch.float32).to(device)

# --- DeepSurv model ---
class DeepSurv(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1)   # NO SIGMOID
        )

    def forward(self, x):
        return self.model(x)

model = DeepSurv(X.shape[1]).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.BCEWithLogitsLoss()

# --- Training Loop ---
for epoch in range(50):
    model.train()
    preds = model(X_train)
    loss = criterion(preds, y_train)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    model.eval()
    val_preds = model(X_val)
    val_loss = criterion(val_preds, y_val)

    print(f"Epoch {epoch:03d} | Train Loss: {loss.item():.4f} | Val Loss: {val_loss.item():.4f}")
# Out:
# Epoch 000 | Train Loss: 0.7111 | Val Loss: 0.7096
# Epoch 001 | Train Loss: 0.7067 | Val Loss: 0.7108
# Epoch 002 | Train Loss: 0.6850 | Val Loss: 0.7131
# Epoch 003 | Train Loss: 0.6836 | Val Loss: 0.7158
# Epoch 004 | Train Loss: 0.6666 | Val Loss: 0.7184
# Epoch 005 | Train Loss: 0.6415 | Val Loss: 0.7208
# Epoch 006 | Train Loss: 0.6544 | Val Loss: 0.7235
# Epoch 007 | Train Loss: 0.6134 | Val Loss: 0.7263
# Epoch 008 | Train Loss: 0.6207 | Val Loss: 0.7289
# Epoch 009 | Train Loss: 0.5953 | Val Loss: 0.7309
# Epoch 010 | Train Loss: 0.5994 | Val Loss: 0.7329
# Epoch 011 | Train Loss: 0.5856 | Val Loss: 0.7346
# Epoch 012 | Train Loss: 0.5718 | Val Loss: 0.7359
# Epoch 013 | Train Loss: 0.5462 | Val Loss: 0.7369
# Epoch 014 | Train Loss: 0.5598 | Val Loss: 0.7381
# Epoch 015 | Train Loss: 0.5530 | Val Loss: 0.7395
# Epoch 016 | Train Loss: 0.5529 | Val Loss: 0.7411
# Epoch 017 | Train Loss: 0.5401 | Val Loss: 0.7429
# Epoch 018 | Train Loss: 0.5222 | Val Loss: 0.7447
# Epoch 019 | Train Loss: 0.5039 | Val Loss: 0.7467
# Epoch 020 | Train Loss: 0.5132 | Val Loss: 0.7490
# Epoch 021 | Train Loss: 0.4918 | Val Loss: 0.7513
# Epoch 022 | Train Loss: 0.4811 | Val Loss: 0.7538
# Epoch 023 | Train Loss: 0.4845 | Val Loss: 0.7565
# Epoch 024 | Train Loss: 0.4671 | Val Loss: 0.7595
# Epoch 025 | Train Loss: 0.4651 | Val Loss: 0.7625
# Epoch 026 | Train Loss: 0.4653 | Val Loss: 0.7654
# Epoch 027 | Train Loss: 0.4541 | Val Loss: 0.7684
# Epoch 028 | Train Loss: 0.4559 | Val Loss: 0.7715
# Epoch 029 | Train Loss: 0.4507 | Val Loss: 0.7745
# Epoch 030 | Train Loss: 0.4462 | Val Loss: 0.7777
# Epoch 031 | Train Loss: 0.4312 | Val Loss: 0.7809
# Epoch 032 | Train Loss: 0.4247 | Val Loss: 0.7843
# Epoch 033 | Train Loss: 0.4204 | Val Loss: 0.7878
# Epoch 034 | Train Loss: 0.4186 | Val Loss: 0.7915
# Epoch 035 | Train Loss: 0.4234 | Val Loss: 0.7952
# Epoch 036 | Train Loss: 0.4152 | Val Loss: 0.7989
# Epoch 037 | Train Loss: 0.3981 | Val Loss: 0.8026
# Epoch 038 | Train Loss: 0.3969 | Val Loss: 0.8061
# Epoch 039 | Train Loss: 0.3932 | Val Loss: 0.8094
# Epoch 040 | Train Loss: 0.3718 | Val Loss: 0.8127
# Epoch 041 | Train Loss: 0.3730 | Val Loss: 0.8162
# Epoch 042 | Train Loss: 0.3721 | Val Loss: 0.8196
# Epoch 043 | Train Loss: 0.3751 | Val Loss: 0.8229
# Epoch 044 | Train Loss: 0.3671 | Val Loss: 0.8264
# Epoch 045 | Train Loss: 0.3701 | Val Loss: 0.8302
# Epoch 046 | Train Loss: 0.3745 | Val Loss: 0.8345
# Epoch 047 | Train Loss: 0.3682 | Val Loss: 0.8390
# Epoch 048 | Train Loss: 0.3523 | Val Loss: 0.8437
# Epoch 049 | Train Loss: 0.3639 | Val Loss: 0.8482

# %%
# --- Clean labels ---
df["survival_label"] = df["survival_label"].astype(str).str.lower()
y = (df["survival_label"] == "long").astype(int).to_numpy()

# --- Scale features ---
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# --- Train/Val split ---
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# ---- Convert to tensors ----
X_train = torch.tensor(X_train, dtype=torch.float32).to(device)
X_val   = torch.tensor(X_val,   dtype=torch.float32).to(device)

y_train = torch.tensor(y_train.astype(float).reshape(-1,1), dtype=torch.float32).to(device)
y_val   = torch.tensor(y_val.astype(float).reshape(-1,1), dtype=torch.float32).to(device)

# --- DeepSurv model ---
class DeepSurv(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1)   # NO SIGMOID
        )

    def forward(self, x):
        return self.model(x)

model = DeepSurv(X.shape[1]).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.BCEWithLogitsLoss()

# --- Training Loop ---
for epoch in range(50):
    model.train()
    preds = model(X_train)
    loss = criterion(preds, y_train)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Validation
    model.eval()
    with torch.no_grad():
        val_preds = model(X_val)
        val_loss = criterion(val_preds, y_val)

    print(f"Epoch {epoch:03d} | Train Loss: {loss.item():.4f} | Val Loss: {val_loss.item():.4f}")
# Out:
# Epoch 000 | Train Loss: 0.6850 | Val Loss: 0.6941
# Epoch 001 | Train Loss: 0.6650 | Val Loss: 0.6996
# Epoch 002 | Train Loss: 0.6523 | Val Loss: 0.7059
# Epoch 003 | Train Loss: 0.6358 | Val Loss: 0.7128
# Epoch 004 | Train Loss: 0.6411 | Val Loss: 0.7194
# Epoch 005 | Train Loss: 0.6177 | Val Loss: 0.7254
# Epoch 006 | Train Loss: 0.6137 | Val Loss: 0.7311
# Epoch 007 | Train Loss: 0.6150 | Val Loss: 0.7375
# Epoch 008 | Train Loss: 0.5875 | Val Loss: 0.7437
# Epoch 009 | Train Loss: 0.5644 | Val Loss: 0.7486
# Epoch 010 | Train Loss: 0.5748 | Val Loss: 0.7526
# Epoch 011 | Train Loss: 0.5488 | Val Loss: 0.7565
# Epoch 012 | Train Loss: 0.5559 | Val Loss: 0.7604
# Epoch 013 | Train Loss: 0.5409 | Val Loss: 0.7636
# Epoch 014 | Train Loss: 0.5244 | Val Loss: 0.7660
# Epoch 015 | Train Loss: 0.5265 | Val Loss: 0.7684
# Epoch 016 | Train Loss: 0.5057 | Val Loss: 0.7708
# Epoch 017 | Train Loss: 0.5099 | Val Loss: 0.7732
# Epoch 018 | Train Loss: 0.4975 | Val Loss: 0.7756
# Epoch 019 | Train Loss: 0.4957 | Val Loss: 0.7779
# Epoch 020 | Train Loss: 0.4677 | Val Loss: 0.7800
# Epoch 021 | Train Loss: 0.4696 | Val Loss: 0.7819
# Epoch 022 | Train Loss: 0.4726 | Val Loss: 0.7839
# Epoch 023 | Train Loss: 0.4505 | Val Loss: 0.7861
# Epoch 024 | Train Loss: 0.4582 | Val Loss: 0.7883
# Epoch 025 | Train Loss: 0.4513 | Val Loss: 0.7907
# Epoch 026 | Train Loss: 0.4529 | Val Loss: 0.7933
# Epoch 027 | Train Loss: 0.4232 | Val Loss: 0.7959
# Epoch 028 | Train Loss: 0.4338 | Val Loss: 0.7985
# Epoch 029 | Train Loss: 0.4290 | Val Loss: 0.8013
# Epoch 030 | Train Loss: 0.4235 | Val Loss: 0.8045
# Epoch 031 | Train Loss: 0.4177 | Val Loss: 0.8076
# Epoch 032 | Train Loss: 0.4121 | Val Loss: 0.8106
# Epoch 033 | Train Loss: 0.4157 | Val Loss: 0.8140
# Epoch 034 | Train Loss: 0.3959 | Val Loss: 0.8174
# Epoch 035 | Train Loss: 0.3813 | Val Loss: 0.8208
# Epoch 036 | Train Loss: 0.3939 | Val Loss: 0.8245
# Epoch 037 | Train Loss: 0.3891 | Val Loss: 0.8284
# Epoch 038 | Train Loss: 0.3499 | Val Loss: 0.8323
# Epoch 039 | Train Loss: 0.3634 | Val Loss: 0.8366
# Epoch 040 | Train Loss: 0.3735 | Val Loss: 0.8409
# Epoch 041 | Train Loss: 0.3732 | Val Loss: 0.8451
# Epoch 042 | Train Loss: 0.3570 | Val Loss: 0.8494
# Epoch 043 | Train Loss: 0.3563 | Val Loss: 0.8534
# Epoch 044 | Train Loss: 0.3562 | Val Loss: 0.8574
# Epoch 045 | Train Loss: 0.3468 | Val Loss: 0.8618
# Epoch 046 | Train Loss: 0.3356 | Val Loss: 0.8659
# Epoch 047 | Train Loss: 0.3564 | Val Loss: 0.8702
# Epoch 048 | Train Loss: 0.3492 | Val Loss: 0.8745
# Epoch 049 | Train Loss: 0.3172 | Val Loss: 0.8787

# %%
model.eval()
with torch.no_grad():
    probs = torch.sigmoid(model(X_val)).cpu().numpy()

# %%
# --- Attach predictions to original dataframe ----
df_val = df.iloc[idx_val].copy()
df_val["Predicted_Survival_Prob"] = probs

df_val.to_csv("multimodal_predictions.csv", index=False)
print("Saved → multimodal_predictions.csv")
# Out:
# Saved → multimodal_predictions.csv

# %%
median_prob = df_val["Predicted_Survival_Prob"].median()
df_val["RiskGroup"] = np.where(
    df_val["Predicted_Survival_Prob"] >= median_prob,
    "Low Risk",
    "High Risk"
)

print(df_val["RiskGroup"].value_counts())
# Out:
# RiskGroup
# Low Risk     5
# High Risk    5
# Name: count, dtype: int64

# %%
np.random.seed(42)

df_val["SurvivalTime"] = np.where(
    df_val["survival_label"].str.lower() == "long",
    np.random.normal(900, 120, df_val.shape[0]),   # long survival
    np.random.normal(350, 80, df_val.shape[0])     # short survival
)

# FIXED
df_val["SurvivalTime"] = df_val["SurvivalTime"].clip(lower=1)

df_val["Event"] = 1  # all observed

# %%
from lifelines import KaplanMeierFitter
import matplotlib.pyplot as plt

kmf = KaplanMeierFitter()

plt.figure(figsize=(8,6))

for group, subdf in df_val.groupby("RiskGroup"):
    kmf.fit(subdf["SurvivalTime"], subdf["Event"], label=group)
    kmf.plot(ci_show=False)

plt.title("Kaplan–Meier Survival by Predicted Risk Group (Multimodal DeepSurv)")
plt.xlabel("Days (simulated)")
plt.ylabel("Survival Probability")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.savefig("KM_multimodal_risk_groups.png", dpi=300)
plt.close()
plt.show()

print("Saved → KM_multimodal_risk_groups.png")
# Out:
# Saved → KM_multimodal_risk_groups.png

# %%
from lifelines import KaplanMeierFitter
import matplotlib.pyplot as plt

kmf = KaplanMeierFitter()

plt.figure(figsize=(8,6))

for group, subdf in df_val.groupby("RiskGroup"):
    kmf.fit(
        durations=subdf["SurvivalTime"],
        event_observed=subdf["Event"],
        label=group
    )
    kmf.plot(ci_show=False)

plt.title("Kaplan–Meier Survival by Predicted Risk Group (Multimodal DeepSurv)")
plt.xlabel("Days (simulated)")
plt.ylabel("Survival Probability")
plt.grid(alpha=0.3)
plt.legend(title="Risk Groups")
plt.tight_layout()

plt.savefig("KM_multimodal_risk_groups.png", dpi=300)
plt.show()

print("Saved → KM_multimodal_risk_groups.png")
# Out:
# Saved → KM_multimodal_risk_groups.png

# %%
from lifelines.statistics import logrank_test

high = df_val[df_val["RiskGroup"] == "High Risk"]
low = df_val[df_val["RiskGroup"] == "Low Risk"]

results = logrank_test(
    high["SurvivalTime"], low["SurvivalTime"],
    event_observed_A=high["Event"],
    event_observed_B=low["Event"]
)

print("Log-rank p-value:", results.p_value)
# Out:
# Log-rank p-value: 0.31877255906456076

# %%
# ============================================================
# 1. Load Multimodal Dataset
# ============================================================
import pandas as pd
import numpy as np

df = pd.read_csv("LUAD_multimodal_dataset.csv")
print("Loaded:", df.shape)
print("Survival label values:", df["survival_label"].unique())

df.head()
# Out:
# Loaded: (40, 227)
# Survival label values: ['Long' 'Short']
#   PatientID survival_label  Longest.Diameter..mm.  \
# 0     R0004           Long                  45.50
# 1     R0013           Long                  41.82
# 2     R0017           Long                  18.95
# 3     R0018          Short                  35.04
# 4     R0019          Short                  31.87
#
#    Short.Axis...Longest.Diameter..mm..  Short.Axis..mm.  Mean..HU.  \
# 0                              1520.73            33.42     -20.13
# 1                               617.67            14.77      -9.56
# 2                               240.46            12.69     -73.58
# 3                              1086.57            31.01      28.45
# 4                               613.64            19.25     -30.00
#
#    StdDev..HU.  Volume..cm..  X5a_3D_MacSpic_NumberOf  \
# 0       136.80         33.06                        0
# 1       119.63         14.78                        0
# 2       151.36          1.76                        0
# 3        93.49         16.85                        0
# 4       146.40         10.97                        0
#
#    X8a_3D_Is_Attached_To_Pleural_Wall  ...  \
# 0                                   0  ...
# 1                                   1  ...
# 2                                   1  ...
# 3                                   1  ...
# 4                                   1  ...
#
#    X3D.Wavelet.decomposition...P1.L2.C5.Layer.1  \
# 0                                  25833.098760
# 1                                  15237.079170
# 2                                   1585.785644
# 3                                  12430.672920
# 4                                   8299.075649
#
#    X3D.Wavelet.decomposition...P1.L2.C6.Layer.1  \
# 0                                   8449.116111
# 1                                   4561.750068
# 2                                   2164.498445
# 3                                   3005.110061
# 4                                   2753.117372
#
#    X3D.Wavelet.decomposition...P1.L2.C7.Layer.1  \
# 0                                    737.184747
# 1                                    613.539088
# 2                                     59.819492
# 3                                    400.538246
# 4                                     89.089983
#
#    X3D.Wavelet.decomposition...P1.L2.C8.Layer.1  Convexity_Mean  \
# 0                                   6172.425054        0.863500
# 1                                   3699.644891        0.845099
# 2                                    491.460387        0.931435
# 3                                   3257.483750        0.917999
# 4                                    381.985943        0.931737
#
#    Conv_Area_Perim  IsAttached  Std_Conv  \
# 0         0.642984    0.863500  0.097923
# 1         0.866819    0.807820  0.027609
# 2         0.918455    0.931435  0.013920
# 3         0.897987    0.917999  0.025730
# 4         0.946039    0.860215  0.039337
#
#                                               Report  \
# 0  CT scan shows left hilum 45.5 mm mass, Stage I...
# 1  CT scan shows right lower lobe 41.82 mm mass, ...
# 2  Stage IV left hilum tumor measuring 18.95 mm. ...
# 3  left hilum lesion (35.04 mm) consistent with S...
# 4  Stage IV right lower lobe tumor measuring 31.8...
#
#                                            ImagePath
# 0  C:\Users\sohel\Downloads\Ai_health\LUAD_CT_SUR...
# 1  C:\Users\sohel\Downloads\Ai_health\LUAD_CT_SUR...
# 2  C:\Users\sohel\Downloads\Ai_health\LUAD_CT_SUR...
# 3  C:\Users\sohel\Downloads\Ai_health\LUAD_CT_SUR...
# 4  C:\Users\sohel\Downloads\Ai_health\LUAD_CT_SUR...
#
# [5 rows x 227 columns]

# %%
# ============================================================
# 2. Clean Labels (long=1, short=0)
# ============================================================
df["survival_label"] = df["survival_label"].astype(str).str.lower()
y = (df["survival_label"] == "long").astype(int).to_numpy()

print("Binary y labels:", np.unique(y))
# Out:
# Binary y labels: [0 1]

# %%
# ============================================================
# 3. Select Numeric Radiomics Features Only
# ============================================================
drop_cols = ["PatientID", "survival_label", "Report", "ImagePath", "SegPath"]

# all numeric radiomics features
radiomics_cols = [
    c for c in df.columns
    if c not in drop_cols and df[c].dtype != "object"
]

print("Numeric radiomics count:", len(radiomics_cols))

# convert to numeric
X_rad = df[radiomics_cols].apply(pd.to_numeric, errors="coerce").fillna(0).values
# Out:
# Numeric radiomics count: 223

# %%
# ============================================================
# 4. Load Precomputed BERT Text Embeddings
# ============================================================
emb = np.load("text_embeddings.npy")
print("Text embedding shape:", emb.shape)   # (40, 768)

# Safety check
assert emb.shape[0] == df.shape[0], "Embedding rows do not match dataset rows!"

# ============================================================
# 5. Select Numeric Radiomics Features
# ============================================================
drop_cols = ["PatientID", "survival_label", "Report", "ImagePath", "SegPath"]

radiomics_cols = [
    c for c in df.columns
    if c not in drop_cols and df[c].dtype != "object"
]

print("Radiomics features:", len(radiomics_cols))

# Convert to numeric
X_rad = df[radiomics_cols].apply(pd.to_numeric, errors="coerce").fillna(0).values

# ============================================================
# 6. Scale Radiomics and Text Separately
# ============================================================
from sklearn.preprocessing import StandardScaler

scaler_rad = StandardScaler()
X_rad_scaled = scaler_rad.fit_transform(X_rad)

scaler_txt = StandardScaler()
emb_scaled = scaler_txt.fit_transform(emb)

# ============================================================
# 7. Combine into Final Multimodal Matrix
# ============================================================
X = np.hstack([X_rad_scaled, emb_scaled])

print("Final X shape:", X.shape)
assert X.shape[0] == df.shape[0], "Row mismatch after combining!"
# Out:
# Text embedding shape: (40, 768)
# Radiomics features: 223
# Final X shape: (40, 991)

# %%
# ============================================================
# 6. Train/Validation Split (with stratification)
# ============================================================
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Track indices for later prediction merge
indices = np.arange(len(X))

X_train, X_val, y_train, y_val, idx_train, idx_val = train_test_split(
    X, y, indices,
    test_size=0.25,
    random_state=42,
    stratify=y
)

# Convert to tensors
X_train = torch.tensor(X_train, dtype=torch.float32).to(device)
X_val   = torch.tensor(X_val,   dtype=torch.float32).to(device)
y_train = torch.tensor(y_train.reshape(-1,1), dtype=torch.float32).to(device)
y_val   = torch.tensor(y_val.reshape(-1,1), dtype=torch.float32).to(device)

# %%
class DeepSurv(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(128, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(64, 1)  # logits
        )

    def forward(self, x):
        return self.model(x)

# %%
epochs = 50

for epoch in range(epochs):
    model.train()

    preds = model(X_train)
    loss = criterion(preds, y_train)

    optimizer.zero_grad()
    loss.backward()

    # 🛑 GRADIENT CLIPPING
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)


    optimizer.step()

    model.eval()
    with torch.no_grad():
        val_preds = model(X_val)
        val_loss = criterion(val_preds, y_val)

    print(f"Epoch {epoch:03d} | Train Loss: {loss.item():.4f} | Val Loss: {val_loss.item():.4f}")
# Out:
# Epoch 000 | Train Loss: 0.6655 | Val Loss: 0.9367
# Epoch 001 | Train Loss: 0.6487 | Val Loss: 0.9288
# Epoch 002 | Train Loss: 0.6536 | Val Loss: 0.9190
# Epoch 003 | Train Loss: 0.6138 | Val Loss: 0.9090
# Epoch 004 | Train Loss: 0.6000 | Val Loss: 0.8986
# Epoch 005 | Train Loss: 0.5844 | Val Loss: 0.8887
# Epoch 006 | Train Loss: 0.5769 | Val Loss: 0.8785
# Epoch 007 | Train Loss: 0.5729 | Val Loss: 0.8679
# Epoch 008 | Train Loss: 0.5290 | Val Loss: 0.8588
# Epoch 009 | Train Loss: 0.5275 | Val Loss: 0.8515
# Epoch 010 | Train Loss: 0.5048 | Val Loss: 0.8466
# Epoch 011 | Train Loss: 0.4995 | Val Loss: 0.8436
# Epoch 012 | Train Loss: 0.4845 | Val Loss: 0.8423
# Epoch 013 | Train Loss: 0.4702 | Val Loss: 0.8432
# Epoch 014 | Train Loss: 0.4718 | Val Loss: 0.8453
# Epoch 015 | Train Loss: 0.4624 | Val Loss: 0.8489
# Epoch 016 | Train Loss: 0.4421 | Val Loss: 0.8535
# Epoch 017 | Train Loss: 0.4378 | Val Loss: 0.8588
# Epoch 018 | Train Loss: 0.4135 | Val Loss: 0.8649
# Epoch 019 | Train Loss: 0.4240 | Val Loss: 0.8707
# Epoch 020 | Train Loss: 0.4041 | Val Loss: 0.8764
# Epoch 021 | Train Loss: 0.4151 | Val Loss: 0.8820
# Epoch 022 | Train Loss: 0.3873 | Val Loss: 0.8876
# Epoch 023 | Train Loss: 0.3600 | Val Loss: 0.8932
# Epoch 024 | Train Loss: 0.3586 | Val Loss: 0.8987
# Epoch 025 | Train Loss: 0.3678 | Val Loss: 0.9043
# Epoch 026 | Train Loss: 0.3429 | Val Loss: 0.9106
# Epoch 027 | Train Loss: 0.3522 | Val Loss: 0.9167
# Epoch 028 | Train Loss: 0.3428 | Val Loss: 0.9233
# Epoch 029 | Train Loss: 0.3363 | Val Loss: 0.9298
# Epoch 030 | Train Loss: 0.3485 | Val Loss: 0.9355
# Epoch 031 | Train Loss: 0.3211 | Val Loss: 0.9410
# Epoch 032 | Train Loss: 0.3171 | Val Loss: 0.9465
# Epoch 033 | Train Loss: 0.3251 | Val Loss: 0.9523
# Epoch 034 | Train Loss: 0.3065 | Val Loss: 0.9579
# Epoch 035 | Train Loss: 0.2993 | Val Loss: 0.9636
# Epoch 036 | Train Loss: 0.3120 | Val Loss: 0.9694
# Epoch 037 | Train Loss: 0.2952 | Val Loss: 0.9753
# Epoch 038 | Train Loss: 0.2911 | Val Loss: 0.9815
# Epoch 039 | Train Loss: 0.2662 | Val Loss: 0.9875
# Epoch 040 | Train Loss: 0.2773 | Val Loss: 0.9934
# Epoch 041 | Train Loss: 0.2760 | Val Loss: 0.9993
# Epoch 042 | Train Loss: 0.2758 | Val Loss: 1.0048
# Epoch 043 | Train Loss: 0.2695 | Val Loss: 1.0098
# Epoch 044 | Train Loss: 0.2599 | Val Loss: 1.0147
# Epoch 045 | Train Loss: 0.2496 | Val Loss: 1.0185
# Epoch 046 | Train Loss: 0.2614 | Val Loss: 1.0220
# Epoch 047 | Train Loss: 0.2555 | Val Loss: 1.0256
# Epoch 048 | Train Loss: 0.2622 | Val Loss: 1.0291
# Epoch 049 | Train Loss: 0.2482 | Val Loss: 1.0324

# %%
# ============================================================
# 9. Predict Validation Probabilities
# ============================================================
model.eval()
with torch.no_grad():
    probs = torch.sigmoid(model(X_val)).detach().cpu().numpy().flatten()

df_val = df.iloc[idx_val].copy()
df_val["Predicted_Survival_Prob"] = probs

df_val.to_csv("multimodal_predictions.csv", index=False)
print("Saved → multimodal_predictions.csv")
# Out:
# Saved → multimodal_predictions.csv

# %%
# ============================================================
# 10. Assign Risk Groups (Median Split)
# ============================================================
median_prob = df_val["Predicted_Survival_Prob"].median()

df_val["RiskGroup"] = np.where(
    df_val["Predicted_Survival_Prob"] >= median_prob,
    "High Risk",
    "Low Risk"
)

print(df_val["RiskGroup"].value_counts())
# Out:
# RiskGroup
# High Risk    5
# Low Risk     5
# Name: count, dtype: int64

# %%
# ============================================================
# 11. Simulate Survival Times for KM Curve (Demo Only)
# ============================================================
np.random.seed(42)

df_val["SurvivalTime"] = np.where(
    df_val["survival_label"] == "long",
    np.random.normal(900, 120, df_val.shape[0]),
    np.random.normal(350, 80,  df_val.shape[0])
)

# Fix invalid values
df_val["SurvivalTime"] = df_val["SurvivalTime"].clip(lower=1)
df_val["Event"] = 1

# %%
# ============================================================
# 12. Kaplan–Meier Survival Curves
# ============================================================
from lifelines import KaplanMeierFitter
import matplotlib.pyplot as plt

kmf = KaplanMeierFitter()

plt.figure(figsize=(8,6))

for group, subdf in df_val.groupby("RiskGroup"):
    kmf.fit(
        durations=subdf["SurvivalTime"],
        event_observed=subdf["Event"],
        label=group
    )
    kmf.plot(ci_show=False)

plt.title("Kaplan–Meier Survival by Predicted Risk Group (Multimodal DeepSurv)")
plt.xlabel("Days (simulated)")
plt.ylabel("Survival Probability")
plt.grid(alpha=0.3)
plt.legend(title="Risk Groups")
plt.tight_layout()

plt.savefig("KM_multimodal_risk_groups.png", dpi=300)
plt.show()

print("Saved → KM_multimodal_risk_groups.png")
# Out:
# Saved → KM_multimodal_risk_groups.png

# %%
# ============================================================
# 13. Log-Rank Test Between Risk Groups
# ============================================================
from lifelines.statistics import logrank_test

high = df_val[df_val["RiskGroup"] == "High Risk"]
low  = df_val[df_val["RiskGroup"] == "Low Risk"]

results = logrank_test(
    high["SurvivalTime"], low["SurvivalTime"],
    event_observed_A=high["Event"],
    event_observed_B=low["Event"]
)

print("Log-rank p-value:", results.p_value)
# Out:
# Log-rank p-value: 0.3187725590645609
