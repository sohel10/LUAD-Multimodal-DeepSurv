# %%
import os
import pandas as pd

# --- 1️⃣ Load your structured + text data ---
df = pd.read_csv("LUAD_multimodal_dataset.csv")

print("📄 Loaded dataset:", df.shape)
print("Columns:", df.columns.tolist())

# --- 2️⃣ Confirm working directory ---
print("\n📂 Current directory:", os.getcwd())
print("🔎 Example files:", [f for f in os.listdir() if f.endswith(".nii")][:10])

# --- 3️⃣ Define a robust matcher for image paths ---
def find_image_path(pid):
    import re
    base_dir = os.getcwd()
    pid = str(pid).strip().upper()

    # List all .nii files in current directory
    nii_files = [f for f in os.listdir(base_dir) if f.endswith(".nii")]

    # --- Try exact filename match first ---
    for f in nii_files:
        if pid in f.upper():
            return os.path.join(base_dir, f)

    # --- Try pattern matching (handles R0004 ↔ R_004) ---
    if pid.startswith("R") and pid[1:].isdigit():
        # remove leading zeros, generate both versions
        pid_num = int(pid[1:])
        patterns = [
            f"R_{pid_num:03d}.nii",
            f"R{pid_num:04d}.nii",
            f"R{pid_num:03d}.nii"
        ]
        for pattern in patterns:
            for f in nii_files:
                if re.fullmatch(pattern.replace(".nii", "") + r"\.nii", f, re.IGNORECASE):
                    return os.path.join(base_dir, f)

    # --- QIN-LSC style ---
    if pid.startswith("QIN-LSC"):
        for f in nii_files:
            if pid in f.upper():
                return os.path.join(base_dir, f)

    return None


# --- 4️⃣ Apply mapping ---
df["ImagePath"] = df["PatientID"].apply(find_image_path)

# --- 5️⃣ Save output ---
df.to_csv("LUAD_multimodal_dataset_with_paths.csv", index=False)
print("\n✅ Saved → LUAD_multimodal_dataset_with_paths.csv")

# --- 6️⃣ Report stats ---
matched = df["ImagePath"].notna().sum()
print(f"\n🧠 Matched images: {matched} out of {len(df)}")
if matched < len(df):
    missing = df[df["ImagePath"].isna()]["PatientID"].tolist()
    print("\n⚠️ Missing matches for:", missing)
else:
    print("🎉 All image paths successfully matched!")
# Out:
# 📄 Loaded dataset: (40, 9)
# Columns: ['PatientID', 'survival_label', 'Longest.Diameter..mm.', 'Short.Axis..mm.', 'Mean..HU.', 'StdDev..HU.', 'Volume..cm..', 'Report', 'ImagePath']
#
# 📂 Current directory: c:\Users\sohel\Downloads\Ai_health\LUAD_CT_SURVIVAL_segmen
# 🔎 Example files: ['QIN-LSC-0009.nii', 'QIN-LSC-0014.nii', 'QIN-LSC-0064.nii', 'R_004.nii', 'R_013.nii', 'R_017.nii', 'R_018.nii', 'R_019.nii', 'R_022.nii', 'R_033.nii']
#
# ✅ Saved → LUAD_multimodal_dataset_with_paths.csv
#
# 🧠 Matched images: 40 out of 40
# 🎉 All image paths successfully matched!

# %%
python merge_multimodal_data.py

# %%
import pandas as pd, random

# Load the LUAD-CT-Survival feature file
df = pd.read_csv("FeaturesWithLabels_1.csv")

# %%
df.head()
# Out:
#      RID survival_label  Longest.Diameter..mm.  \
# 0  R0004           Long                  45.50
# 1  R0013           Long                  41.82
# 2  R0017           Long                  18.95
# 3  R0018          Short                  35.04
# 4  R0019          Short                  31.87
#
#    Short.Axis...Longest.Diameter..mm..  Short.Axis..mm.  Mean..HU.  \
# 0                              1520.73            33.42     -20.13
# 1                               617.67            14.77      -9.56
# 2                               240.46            12.69     -73.58
# 3                              1086.57            31.01      28.45
# 4                               613.64            19.25     -30.00
#
#    StdDev..HU.  Volume..cm..  X5a_3D_MacSpic_NumberOf  \
# 0       136.80         33.06                        0
# 1       119.63         14.78                        0
# 2       151.36          1.76                        0
# 3        93.49         16.85                        0
# 4       146.40         10.97                        0
#
#    X8a_3D_Is_Attached_To_Pleural_Wall  ...  \
# 0                                   0  ...
# 1                                   1  ...
# 2                                   1  ...
# 3                                   1  ...
# 4                                   1  ...
#
#    X3D.Wavelet.decomposition...P1.L2.C3.Layer.1  \
# 0                                    922.503735
# 1                                    717.342696
# 2                                     11.057679
# 3                                    494.811919
# 4                                     89.742340
#
#    X3D.Wavelet.decomposition...P1.L2.C4.Layer.1  \
# 0                                   7055.561581
# 1                                   4189.960074
# 2                                     15.946198
# 3                                   3947.601380
# 4                                    571.684059
#
#    X3D.Wavelet.decomposition...P1.L2.C5.Layer.1  \
# 0                                  25833.098760
# 1                                  15237.079170
# 2                                   1585.785644
# 3                                  12430.672920
# 4                                   8299.075649
#
#    X3D.Wavelet.decomposition...P1.L2.C6.Layer.1  \
# 0                                   8449.116111
# 1                                   4561.750068
# 2                                   2164.498445
# 3                                   3005.110061
# 4                                   2753.117372
#
#    X3D.Wavelet.decomposition...P1.L2.C7.Layer.1  \
# 0                                    737.184747
# 1                                    613.539088
# 2                                     59.819492
# 3                                    400.538246
# 4                                     89.089983
#
#    X3D.Wavelet.decomposition...P1.L2.C8.Layer.1  Convexity_Mean  \
# 0                                   6172.425054        0.863500
# 1                                   3699.644891        0.845099
# 2                                    491.460387        0.931435
# 3                                   3257.483750        0.917999
# 4                                    381.985943        0.931737
#
#    Conv_Area_Perim  IsAttached  Std_Conv
# 0         0.642984    0.863500  0.097923
# 1         0.866819    0.807820  0.027609
# 2         0.918455    0.931435  0.013920
# 3         0.897987    0.917999  0.025730
# 4         0.946039    0.860215  0.039337
#
# [5 rows x 225 columns]

# %%
df.columns.tolist()
# Out:
# ['RID',
#  'survival_label',
#  'Longest.Diameter..mm.',
#  'Short.Axis...Longest.Diameter..mm..',
#  'Short.Axis..mm.',
#  'Mean..HU.',
#  'StdDev..HU.',
#  'Volume..cm..',
#  'X5a_3D_MacSpic_NumberOf',
#  'X8a_3D_Is_Attached_To_Pleural_Wall',
#  'X8b_3D_Relative_Border_To_Lung',
#  'X8c_3D_Relative_Border_To_PleuralWall',
#  'X8d_3D_Ratio_Free_To_Attached',
#  'X9a_3D_FractionalAnisotropy',
#  'X9b_3D_Circularity',
#  'X9c_3D_Compactness',
#  'X9d_3D_AV_Dist_COG_To_Border_.mm.',
#  'X9e_3D_SD_Dist_COG_To_Border_.mm.',
#  'X9f_3D_MIN_Dist_COG_To_Border_.mm.',
#  'X9g_3D_MAX_Dist_COG_To_Border_.mm.',
#  'X10a_3D_Relative_Volume_AirSpaces',
#  'X10b_3D_Number_AirSpaces',
#  'X10c_3D_Av_Volume_AirSpaces_.mm..',
#  'X10d_3D_SD_Volume_AirSpaces_.mm..',
#  'Asymmetry',
#  'Compactness',
#  'Density',
#  'Elliptic.Fit',
#  'Main.direction',
#  'Radius.of.largest.enclosed.ellipse',
#  'Radius.of.smallest.enclosing.ellipse',
#  'Shape.index',
#  'Roundness',
#  'Rectangular.Fit',
#  'Area..Pxl.',
#  'Volume..Pxl.',
#  'Number.of.pixels',
#  'Width..Pxl.',
#  'Thickness..Pxl.',
#  'Length..Pxl.',
#  'Length.Thickness',
#  'Length.Width',
#  'Border.length..Pxl.',
#  'avgCoocurrence.Homo',
#  'avgCoocurrence.MP',
#  'avgCoocurrence.contrast',
#  'avgCoocurrence.energy',
#  'avgCoocurrence.entropy',
#  'avgCoocurrence.mean',
#  'avgGLN',
#  'avgHGRE',
#  'avgLGRE',
#  'avgLRE',
#  'avgLRHGE',
#  'avgLRLGE',
#  'avgRLN',
#  'avgRP',
#  'avgSRE',
#  'avgSRHGE',
#  'avgSRLGE',
#  'X3D.Laws.features..E5.E5.E5.Layer.1',
#  'X3D.Laws.features..E5.E5.L5.Layer.1',
#  'X3D.Laws.features..E5.E5.R5.Layer.1',
#  'X3D.Laws.features..E5.E5.S5.Layer.1',
#  'X3D.Laws.features..E5.E5.W5.Layer.1',
#  'X3D.Laws.features..E5.L5.E5.Layer.1',
#  'X3D.Laws.features..E5.L5.L5.Layer.1',
#  'X3D.Laws.features..E5.L5.R5.Layer.1',
#  'X3D.Laws.features..E5.L5.S5.Layer.1',
#  'X3D.Laws.features..E5.L5.W5.Layer.1',
#  'X3D.Laws.features..E5.R5.E5.Layer.1',
#  'X3D.Laws.features..E5.R5.L5.Layer.1',
#  'X3D.Laws.features..E5.R5.R5.Layer.1',
#  'X3D.Laws.features..E5.R5.S5.Layer.1',
#  'X3D.Laws.features..E5.R5.W5.Layer.1',
#  'X3D.Laws.features..E5.S5.E5.Layer.1',
#  'X3D.Laws.features..E5.S5.L5.Layer.1',
#  'X3D.Laws.features..E5.S5.R5.Layer.1',
#  'X3D.Laws.features..E5.S5.S5.Layer.1',
#  'X3D.Laws.features..E5.S5.W5.Layer.1',
#  'X3D.Laws.features..E5.W5.E5.Layer.1',
#  'X3D.Laws.features..E5.W5.L5.Layer.1',
#  'X3D.Laws.features..E5.W5.R5.Layer.1',
#  'X3D.Laws.features..E5.W5.S5.Layer.1',
#  'X3D.Laws.features..E5.W5.W5.Layer.1',
#  'X3D.Laws.features..L5.E5.E5.Layer.1',
#  'X3D.Laws.features..L5.E5.L5.Layer.1',
#  'X3D.Laws.features..L5.E5.R5.Layer.1',
#  'X3D.Laws.features..L5.E5.S5.Layer.1',
#  'X3D.Laws.features..L5.E5.W5.Layer.1',
#  'X3D.Laws.features..L5.L5.E5.Layer.1',
#  'X3D.Laws.features..L5.L5.L5.Layer.1',
#  'X3D.Laws.features..L5.L5.R5.Layer.1',
#  'X3D.Laws.features..L5.L5.S5.Layer.1',
#  'X3D.Laws.features..L5.L5.W5.Layer.1',
#  'X3D.Laws.features..L5.R5.E5.Layer.1',
#  'X3D.Laws.features..L5.R5.L5.Layer.1',
#  'X3D.Laws.features..L5.R5.R5.Layer.1',
#  'X3D.Laws.features..L5.R5.S5.Layer.1',
#  'X3D.Laws.features..L5.R5.W5.Layer.1',
#  'X3D.Laws.features..L5.S5.E5.Layer.1',
#  'X3D.Laws.features..L5.S5.L5.Layer.1',
#  'X3D.Laws.features..L5.S5.R5.Layer.1',
#  'X3D.Laws.features..L5.S5.S5.Layer.1',
#  'X3D.Laws.features..L5.S5.W5.Layer.1',
#  'X3D.Laws.features..L5.W5.E5.Layer.1',
#  'X3D.Laws.features..L5.W5.L5.Layer.1',
#  'X3D.Laws.features..L5.W5.R5.Layer.1',
#  'X3D.Laws.features..L5.W5.S5.Layer.1',
#  'X3D.Laws.features..L5.W5.W5.Layer.1',
#  'X3D.Laws.features..R5.E5.E5.Layer.1',
#  'X3D.Laws.features..R5.E5.L5.Layer.1',
#  'X3D.Laws.features..R5.E5.R5.Layer.1',
#  'X3D.Laws.features..R5.E5.S5.Layer.1',
#  'X3D.Laws.features..R5.E5.W5.Layer.1',
#  'X3D.Laws.features..R5.L5.E5.Layer.1',
#  'X3D.Laws.features..R5.L5.L5.Layer.1',
#  'X3D.Laws.features..R5.L5.R5.Layer.1',
#  'X3D.Laws.features..R5.L5.S5.Layer.1',
#  'X3D.Laws.features..R5.L5.W5.Layer.1',
#  'X3D.Laws.features..R5.R5.E5.Layer.1',
#  'X3D.Laws.features..R5.R5.L5.Layer.1',
#  'X3D.Laws.features..R5.R5.R5.Layer.1',
#  'X3D.Laws.features..R5.R5.S5.Layer.1',
#  'X3D.Laws.features..R5.R5.W5.Layer.1',
#  'X3D.Laws.features..R5.S5.E5.Layer.1',
#  'X3D.Laws.features..R5.S5.L5.Layer.1',
#  'X3D.Laws.features..R5.S5.R5.Layer.1',
#  'X3D.Laws.features..R5.S5.S5.Layer.1',
#  'X3D.Laws.features..R5.S5.W5.Layer.1',
#  'X3D.Laws.features..R5.W5.E5.Layer.1',
#  'X3D.Laws.features..R5.W5.L5.Layer.1',
#  'X3D.Laws.features..R5.W5.R5.Layer.1',
#  'X3D.Laws.features..R5.W5.S5.Layer.1',
#  'X3D.Laws.features..R5.W5.W5.Layer.1',
#  'X3D.Laws.features..S5.E5.E5.Layer.1',
#  'X3D.Laws.features..S5.E5.L5.Layer.1',
#  'X3D.Laws.features..S5.E5.R5.Layer.1',
#  'X3D.Laws.features..S5.E5.S5.Layer.1',
#  'X3D.Laws.features..S5.E5.W5.Layer.1',
#  'X3D.Laws.features..S5.L5.E5.Layer.1',
#  'X3D.Laws.features..S5.L5.L5.Layer.1',
#  'X3D.Laws.features..S5.L5.R5.Layer.1',
#  'X3D.Laws.features..S5.L5.S5.Layer.1',
#  'X3D.Laws.features..S5.L5.W5.Layer.1',
#  'X3D.Laws.features..S5.R5.E5.Layer.1',
#  'X3D.Laws.features..S5.R5.L5.Layer.1',
#  'X3D.Laws.features..S5.R5.R5.Layer.1',
#  'X3D.Laws.features..S5.R5.S5.Layer.1',
#  'X3D.Laws.features..S5.R5.W5.Layer.1',
#  'X3D.Laws.features..S5.S5.E5.Layer.1',
#  'X3D.Laws.features..S5.S5.L5.Layer.1',
#  'X3D.Laws.features..S5.S5.R5.Layer.1',
#  'X3D.Laws.features..S5.S5.S5.Layer.1',
#  'X3D.Laws.features..S5.S5.W5.Layer.1',
#  'X3D.Laws.features..S5.W5.E5.Layer.1',
#  'X3D.Laws.features..S5.W5.L5.Layer.1',
#  'X3D.Laws.features..S5.W5.R5.Layer.1',
#  'X3D.Laws.features..S5.W5.S5.Layer.1',
#  'X3D.Laws.features..S5.W5.W5.Layer.1',
#  'X3D.Laws.features..W5.E5.E5.Layer.1',
#  'X3D.Laws.features..W5.E5.L5.Layer.1',
#  'X3D.Laws.features..W5.E5.R5.Layer.1',
#  'X3D.Laws.features..W5.E5.S5.Layer.1',
#  'X3D.Laws.features..W5.E5.W5.Layer.1',
#  'X3D.Laws.features..W5.L5.E5.Layer.1',
#  'X3D.Laws.features..W5.L5.L5.Layer.1',
#  'X3D.Laws.features..W5.L5.R5.Layer.1',
#  'X3D.Laws.features..W5.L5.S5.Layer.1',
#  'X3D.Laws.features..W5.L5.W5.Layer.1',
#  'X3D.Laws.features..W5.R5.E5.Layer.1',
#  'X3D.Laws.features..W5.R5.L5.Layer.1',
#  'X3D.Laws.features..W5.R5.R5.Layer.1',
#  'X3D.Laws.features..W5.R5.S5.Layer.1',
#  'X3D.Laws.features..W5.S5.E5.Layer.1',
#  'X3D.Laws.features..W5.S5.L5.Layer.1',
#  'X3D.Laws.features..W5.R5.W5.Layer.1',
#  'X3D.Laws.features..W5.S5.R5.Layer.1',
#  'X3D.Laws.features..W5.S5.S5.Layer.1',
#  'X3D.Laws.features..W5.S5.W5.Layer.1',
#  'X3D.Laws.features..W5.W5.E5.Layer.1',
#  'X3D.Laws.features..W5.W5.L5.Layer.1',
#  'X3D.Laws.features..W5.W5.R5.Layer.1',
#  'X3D.Laws.features..W5.W5.S5.Layer.1',
#  'X3D.Laws.features..W5.W5.W5.Layer.1',
#  'Histogram..Mean.Layer.1',
#  'Histogram..SD.Layer.1',
#  'Histogram.ENERGY.Layer.1',
#  'Histogram.ENTROPY.Layer.1',
#  'Histogram.KUR.Layer.1',
#  'Histogram.SKEW.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C9.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C9.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C10.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C11.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C12.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C13.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C14.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C15.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C1.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C2.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C3.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C4.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C5.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C6.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C7.Layer.1',
#  'X3D.Wavelet.decomposition...P2.L2.C8.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C11.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C10.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C12.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C13.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C14.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C15.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C1.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C2.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C3.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C4.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C5.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C6.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C7.Layer.1',
#  'X3D.Wavelet.decomposition...P1.L2.C8.Layer.1',
#  'Convexity_Mean',
#  'Conv_Area_Perim',
#  'IsAttached',
#  'Std_Conv']

# %%
# Rename RID → PatientID
df.rename(columns={"RID": "PatientID"}, inplace=True)

templates = [
    "CT scan shows {location} {size} mm mass, Stage {stage}, {response} to treatment.",
    "{location} lesion ({size} mm) consistent with Stage {stage} adenocarcinoma. {response}.",
    "Stage {stage} {location} tumor measuring {size} mm. {response} observed."
]

locations = ["left upper lobe", "right lower lobe", "left hilum", "right upper lobe"]
responses = ["partial response", "stable disease", "disease progression", "complete remission"]

def make_report(row):
    size = row.get("Longest.Diameter..mm.", random.randint(20, 50))
    # Randomly assign stage since dataset has no explicit stage column
    stage = random.choice(["II", "III", "IV"])
    location = random.choice(locations)
    response = random.choice(responses)
    return random.choice(templates).format(size=size, stage=stage, location=location, response=response)

df["Report"] = df.apply(make_report, axis=1)

# Save the synthetic reports
df[["PatientID", "Report"]].to_csv("radiology_reports.csv", index=False)

print("✅ File saved → radiology_reports.csv")

# %%
df_rad = pd.read_csv("FeaturesWithLabels_1.csv")
df_txt = pd.read_csv("radiology_reports.csv")

# make keys match
df_rad.rename(columns={"RID": "PatientID"}, inplace=True)

# merge
df = df_rad.merge(df_txt, on="PatientID", how="inner")

print(df.head())
# Out:
#   PatientID survival_label  Longest.Diameter..mm.  \
# 0     R0004           Long                  45.50
# 1     R0013           Long                  41.82
# 2     R0017           Long                  18.95
# 3     R0018          Short                  35.04
# 4     R0019          Short                  31.87
#
#    Short.Axis...Longest.Diameter..mm..  Short.Axis..mm.  Mean..HU.  \
# 0                              1520.73            33.42     -20.13
# 1                               617.67            14.77      -9.56
# 2                               240.46            12.69     -73.58
# 3                              1086.57            31.01      28.45
# 4                               613.64            19.25     -30.00
#
#    StdDev..HU.  Volume..cm..  X5a_3D_MacSpic_NumberOf  \
# 0       136.80         33.06                        0
# 1       119.63         14.78                        0
# 2       151.36          1.76                        0
# 3        93.49         16.85                        0
# 4       146.40         10.97                        0
#
#    X8a_3D_Is_Attached_To_Pleural_Wall  ...  \
# 0                                   0  ...
# 1                                   1  ...
# 2                                   1  ...
# 3                                   1  ...
# 4                                   1  ...
#
#    X3D.Wavelet.decomposition...P1.L2.C4.Layer.1  \
# 0                                   7055.561581
# 1                                   4189.960074
# 2                                     15.946198
# 3                                   3947.601380
# 4                                    571.684059
#
#    X3D.Wavelet.decomposition...P1.L2.C5.Layer.1  \
# 0                                  25833.098760
# 1                                  15237.079170
# 2                                   1585.785644
# 3                                  12430.672920
# 4                                   8299.075649
#
#    X3D.Wavelet.decomposition...P1.L2.C6.Layer.1  \
# 0                                   8449.116111
# 1                                   4561.750068
# 2                                   2164.498445
# 3                                   3005.110061
# 4                                   2753.117372
#
#    X3D.Wavelet.decomposition...P1.L2.C7.Layer.1  \
# 0                                    737.184747
# 1                                    613.539088
# 2                                     59.819492
# 3                                    400.538246
# 4                                     89.089983
#
#    X3D.Wavelet.decomposition...P1.L2.C8.Layer.1  Convexity_Mean  \
# 0                                   6172.425054        0.863500
# 1                                   3699.644891        0.845099
# 2                                    491.460387        0.931435
# 3                                   3257.483750        0.917999
# 4                                    381.985943        0.931737
#
#    Conv_Area_Perim  IsAttached  Std_Conv  \
# 0         0.642984    0.863500  0.097923
# 1         0.866819    0.807820  0.027609
# 2         0.918455    0.931435  0.013920
# 3         0.897987    0.917999  0.025730
# 4         0.946039    0.860215  0.039337
#
#                                               Report
# 0  CT scan shows left hilum 45.5 mm mass, Stage I...
# 1  CT scan shows right lower lobe 41.82 mm mass, ...
# 2  Stage IV left hilum tumor measuring 18.95 mm. ...
# 3  left hilum lesion (35.04 mm) consistent with S...
# 4  Stage IV right lower lobe tumor measuring 31.8...
#
# [5 rows x 226 columns]
